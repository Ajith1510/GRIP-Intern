# %% [markdown]
# # The Sparks Foundation || GRIPMAR21
#
# ## Data Science and Business Analytics
#
# ### TASK 4 : Exploratory Data Analysis - Terrorism
#
# ### Author : Ajith Prasanna R

# %% [markdown]
# To Perform 'Exploratory Data Analysis' on dataset 'Global Terrorism', to find out the hot zone of terrorism and derive all security issues and insights from EDA.

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('D:\Spark Intern\globalterrorismdb_0718dist.csv',encoding='ISO-8859-1')
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region   ...    addnotes scite1 scite2  scite3  \
# 0  Dominican Republic       2   ...         NaN    NaN    NaN     NaN
# 1              Mexico       1   ...         NaN    NaN    NaN     NaN
# 2         Philippines       5   ...         NaN    NaN    NaN     NaN
# 3              Greece       8   ...         NaN    NaN    NaN     NaN
# 4               Japan       4   ...         NaN    NaN    NaN     NaN
#
#    dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0      PGIS        0         0        0       0      NaN
# 1      PGIS        0         1        1       1      NaN
# 2      PGIS       -9        -9        1       1      NaN
# 3      PGIS       -9        -9        1       1      NaN
# 4      PGIS       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
df.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region   ...    addnotes  \
# 181686      182      Somalia      11   ...         NaN
# 181687      200        Syria      10   ...         NaN
# 181688      160  Philippines       5   ...         NaN
# 181689       92        India       6   ...         NaN
# 181690      160  Philippines       5   ...         NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [5 rows x 135 columns]

# %%
df.shape
# Out:
# (181691, 135)

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ### Checking the missing values

# %%
for col in df.columns:
  print(col, ":", (df[col].isnull().sum()/len(df))*100)
# Out:
# eventid : 0.0
# iyear : 0.0
# imonth : 0.0
# iday : 0.0
# approxdate : 94.91499303762983
# extended : 0.0
# resolution : 98.77814531264619
# country : 0.0
# country_txt : 0.0
# region : 0.0
# region_txt : 0.0
# provstate : 0.23171208260177995
# city : 0.23886708752772565
# latitude : 2.507554034046816
# longitude : 2.5081044190411195
# specificity : 0.0033023099658210917
# vicinity : 0.0
# location : 69.45638474112641
# summary : 36.396409288297164
# crit1 : 0.0
# crit2 : 0.0
# crit3 : 0.0
# doubtterr : 0.0005503849943035153
# alternative : 84.03278093026071
# alternative_txt : 84.03278093026071
# multiple : 0.0005503849943035153
# success : 0.0
# suicide : 0.0
# attacktype1 : 0.0
# attacktype1_txt : 0.0
# attacktype2 : 96.52486914596761
# attacktype2_txt : 96.52486914596761
# attacktype3 : 99.7644352224381
# attacktype3_txt : 99.7644352224381
# targtype1 : 0.0
# targtype1_txt : 0.0
# targsubtype1 : 5.709143545910364
# targsubtype1_txt : 5.709143545910364
# corp1 : 23.418881507614575
# target1 : 0.35004485637703575
# natlty1 : 0.8580502061191804
# natlty1_txt : 0.8580502061191804
# targtype2 : 93.86650962348162
# targtype2_txt : 93.86650962348162
# targsubtype2 : 94.11913633586694
# targsubtype2_txt : 94.11913633586694
# corp2 : 94.43175501263134
# target2 : 93.93475736277526
# natlty2 : 94.04043128168153
# natlty2_txt : 94.04043128168153
# targtype3 : 99.35274724669907
# targtype3_txt : 99.35274724669907
# targsubtype3 : 99.39622766124904
# targsubtype3_txt : 99.39622766124904
# corp3 : 99.4353049958446
# target3 : 99.35329763169337
# natlty3 : 99.36870841153387
# natlty3_txt : 99.36870841153387
# gname : 0.0
# gsubname : 96.75823238355228
# gname2 : 98.89207500646702
# gsubname2 : 99.91193840091144
# gname3 : 99.82167526184567
# gsubname3 : 99.98899230011394
# motive : 72.17198430301997
# guncertain1 : 0.2091462978353358
# guncertain2 : 98.92399733613662
# guncertain3 : 99.82387680182288
# individual : 0.0
# nperps : 39.14062886989449
# nperpcap : 38.24570286915698
# claimed : 36.39145582334844
# claimmode : 89.49700315370602
# claimmode_txt : 89.49700315370602
# claim2 : 98.95977236076635
# claimmode2 : 99.66096284350904
# claimmode2_txt : 99.66096284350904
# claim3 : 99.82497757181147
# claimmode3 : 99.92679879575763
# claimmode3_txt : 99.92679879575763
# compclaim : 97.33668701256529
# weaptype1 : 0.0
# weaptype1_txt : 0.0
# weapsubtype1 : 11.430395561695406
# weapsubtype1_txt : 11.430395561695406
# weaptype2 : 92.77509617977775
# weaptype2_txt : 92.77509617977775
# weapsubtype2 : 93.64745639574883
# weapsubtype2_txt : 93.64745639574883
# weaptype3 : 98.97463275561255
# weaptype3_txt : 98.97463275561255
# weapsubtype3 : 99.06819820464415
# weapsubtype3_txt : 99.06819820464415
# weaptype4 : 99.95982189541584
# weaptype4_txt : 99.95982189541584
# weapsubtype4 : 99.96147305039875
# weapsubtype4_txt : 99.96147305039875
# weapdetail : 37.24455256451888
# nkill : 5.676120446252153
# nkillus : 35.470111342884344
# nkillter : 36.85267844857478
# nwound : 8.977329642084639
# nwoundus : 35.61100990142605
# nwoundte : 38.05526966112796
# property : 0.0
# propextent : 64.7395853399453
# propextent_txt : 64.7395853399453
# propvalue : 78.54103945710024
# propcomment : 68.10023611516256
# ishostkid : 0.09796852898602572
# nhostkid : 92.53017485731269
# nhostkidus : 92.56044603199939
# nhours : 97.76378576814481
# ndays : 95.52867230627824
# divert : 99.82167526184567
# kidhijcountry : 98.18097759382688
# ransom : 57.41065875579968
# ransomamt : 99.25698025769026
# ransomamtus : 99.69013324820712
# ransompaid : 99.57400201440907
# ransompaidus : 99.69618748314446
# ransomnote : 99.71710211292799
# hostkidoutcome : 93.95071852761006
# hostkidoutcome_txt : 93.95071852761006
# nreleased : 94.27599605924344
# addnotes : 84.43015889614786
# scite1 : 36.430533157943984
# scite2 : 57.65723123324765
# scite3 : 76.04944658788823
# dbsource : 0.0
# INT_LOG : 0.0
# INT_IDEO : 0.0
# INT_MISC : 0.0
# INT_ANY : 0.0
# related : 86.21946051262859

# %% [markdown]
# ### Handling the missing values

# %%
# Dropping columns where more than 160000 records are empty
new_df = df.dropna(thresh=160000,axis=1)

# %%
new_df
# Out:
#              eventid  iyear  imonth  iday  extended  country  \
# 0       197000000001   1970       7     2         0       58
# 1       197000000002   1970       0     0         0      130
# 2       197001000001   1970       1     0         0      160
# 3       197001000002   1970       1     0         0       78
# 4       197001000003   1970       1     0         0      101
# 5       197001010002   1970       1     1         0      217
# 6       197001020001   1970       1     2         0      218
# 7       197001020002   1970       1     2         0      217
# 8       197001020003   1970       1     2         0      217
# 9       197001030001   1970       1     3         0      217
# 10      197001050001   1970       1     1         0      217
# 11      197001060001   1970       1     6         0      217
# 12      197001080001   1970       1     8         0       98
# 13      197001090001   1970       1     9         0      217
# 14      197001090002   1970       1     9         0      217
# 15      197001100001   1970       1    10         0      499
# 16      197001110001   1970       1    11         0       65
# 17      197001120001   1970       1    12         0      217
# 18      197001120002   1970       1    12         0      217
# 19      197001130001   1970       1    13         0      217
# 20      197001140001   1970       1    14         0      217
# 21      197001150001   1970       1    15         0      218
# 22      197001190002   1970       1    19         0      217
# 23      197001190003   1970       1    19         0      217
# 24      197001190004   1970       1    19         0      217
# 25      197001200001   1970       1    20         0       83
# 26      197001210001   1970       1    21         0      160
# 27      197001220001   1970       1    22         0      222
# 28      197001220002   1970       1    22         0      217
# 29      197001250001   1970       1    25         0      217
# ...              ...    ...     ...   ...       ...      ...
# 181661  201712300019   2017      12    28         0       92
# 181662  201712300020   2017      12    30         0      160
# 181663  201712300021   2017      12    30         0       92
# 181664  201712300022   2017      12    30         0      603
# 181665  201712300023   2017      12    30         0       92
# 181666  201712300025   2017      12    30         0      147
# 181667  201712300026   2017      12    30         0      200
# 181668  201712310001   2017      12    31         0       95
# 181669  201712310002   2017      12    30         0       95
# 181670  201712310003   2017      12    31         0       95
# 181671  201712310004   2017      12    31         0       95
# 181672  201712310005   2017      12    31         0       92
# 181673  201712310006   2017      12    31         0        4
# 181674  201712310007   2017      12    31         0       95
# 181675  201712310008   2017      12    31         0      182
# 181676  201712310009   2017      12    31         0        4
# 181677  201712310010   2017      12    31         0      160
# 181678  201712310011   2017      12    30         0      160
# 181679  201712310012   2017      12    31         0       95
# 181680  201712310013   2017      12    31         0      182
# 181681  201712310016   2017      12    31         0      160
# 181682  201712310017   2017      12    31         0       98
# 181683  201712310018   2017      12    31         0        4
# 181684  201712310019   2017      12    31         0       92
# 181685  201712310020   2017      12    31         0        4
# 181686  201712310022   2017      12    31         0      182
# 181687  201712310029   2017      12    31         0      200
# 181688  201712310030   2017      12    31         0      160
# 181689  201712310031   2017      12    31         0       92
# 181690  201712310032   2017      12    31         0      160
#
#                country_txt  region                   region_txt  \
# 0       Dominican Republic       2  Central America & Caribbean
# 1                   Mexico       1                North America
# 2              Philippines       5               Southeast Asia
# 3                   Greece       8               Western Europe
# 4                    Japan       4                    East Asia
# 5            United States       1                North America
# 6                  Uruguay       3                South America
# 7            United States       1                North America
# 8            United States       1                North America
# 9            United States       1                North America
# 10           United States       1                North America
# 11           United States       1                North America
# 12                   Italy       8               Western Europe
# 13           United States       1                North America
# 14           United States       1                North America
# 15      East Germany (GDR)       9               Eastern Europe
# 16                Ethiopia      11           Sub-Saharan Africa
# 17           United States       1                North America
# 18           United States       1                North America
# 19           United States       1                North America
# 20           United States       1                North America
# 21                 Uruguay       3                South America
# 22           United States       1                North America
# 23           United States       1                North America
# 24           United States       1                North America
# 25               Guatemala       2  Central America & Caribbean
# 26             Philippines       5               Southeast Asia
# 27               Venezuela       3                South America
# 28           United States       1                North America
# 29           United States       1                North America
# ...                    ...     ...                          ...
# 181661               India       6                   South Asia
# 181662         Philippines       5               Southeast Asia
# 181663               India       6                   South Asia
# 181664      United Kingdom       8               Western Europe
# 181665               India       6                   South Asia
# 181666             Nigeria      11           Sub-Saharan Africa
# 181667               Syria      10   Middle East & North Africa
# 181668                Iraq      10   Middle East & North Africa
# 181669                Iraq      10   Middle East & North Africa
# 181670                Iraq      10   Middle East & North Africa
# 181671                Iraq      10   Middle East & North Africa
# 181672               India       6                   South Asia
# 181673         Afghanistan       6                   South Asia
# 181674                Iraq      10   Middle East & North Africa
# 181675             Somalia      11           Sub-Saharan Africa
# 181676         Afghanistan       6                   South Asia
# 181677         Philippines       5               Southeast Asia
# 181678         Philippines       5               Southeast Asia
# 181679                Iraq      10   Middle East & North Africa
# 181680             Somalia      11           Sub-Saharan Africa
# 181681         Philippines       5               Southeast Asia
# 181682               Italy       8               Western Europe
# 181683         Afghanistan       6                   South Asia
# 181684               India       6                   South Asia
# 181685         Afghanistan       6                   South Asia
# 181686             Somalia      11           Sub-Saharan Africa
# 181687               Syria      10   Middle East & North Africa
# 181688         Philippines       5               Southeast Asia
# 181689               India       6                   South Asia
# 181690         Philippines       5               Southeast Asia
#
#                   provstate   ...     \
# 0                       NaN   ...
# 1                   Federal   ...
# 2                    Tarlac   ...
# 3                    Attica   ...
# 4                   Fukouka   ...
# 5                  Illinois   ...
# 6                Montevideo   ...
# 7                California   ...
# 8                 Wisconsin   ...
# 9                 Wisconsin   ...
# 10                Wisconsin   ...
# 11                 Colorado   ...
# 12                    Lazio   ...
# 13                 Michigan   ...
# 14              Puerto Rico   ...
# 15                   Berlin   ...
# 16                  Unknown   ...
# 17                 New York   ...
# 18              Puerto Rico   ...
# 19               Washington   ...
# 20                 Illinois   ...
# 21               Montevideo   ...
# 22               Washington   ...
# 23               Washington   ...
# 24               New Jersey   ...
# 25                Guatemala   ...
# 26      Metropolitan Manila   ...
# 27                  Caracas   ...
# 28                 Nebraska   ...
# 29              Mississippi   ...
# ...                     ...   ...
# 181661       Andhra Pradesh   ...
# 181662       Davao Oriental   ...
# 181663               Kerala   ...
# 181664     Northern Ireland   ...
# 181665         Chhattisgarh   ...
# 181666                Borno   ...
# 181667             Damascus   ...
# 181668               Kirkuk   ...
# 181669               Kirkuk   ...
# 181670               Diyala   ...
# 181671              Saladin   ...
# 181672    Jammu and Kashmir   ...
# 181673            Nangarhar   ...
# 181674              Nineveh   ...
# 181675             Banaadir   ...
# 181676                Logar   ...
# 181677          Maguindanao   ...
# 181678       North Cotabato   ...
# 181679               Diyala   ...
# 181680               Bakool   ...
# 181681          Maguindanao   ...
# 181682               Marche   ...
# 181683               Faryab   ...
# 181684                Assam   ...
# 181685               Faryab   ...
# 181686      Middle Shebelle   ...
# 181687             Lattakia   ...
# 181688          Maguindanao   ...
# 181689              Manipur   ...
# 181690          Maguindanao   ...
#
#                                  weapsubtype1_txt  nkill  nwound  property  \
# 0                                             NaN    1.0     0.0         0
# 1                                             NaN    0.0     0.0         0
# 2                                             NaN    1.0     0.0         0
# 3                          Unknown Explosive Type    NaN     NaN         1
# 4                                             NaN    NaN     NaN         1
# 5                                Unknown Gun Type    0.0     0.0         1
# 6               Automatic or Semi-Automatic Rifle    0.0     0.0         0
# 7                          Unknown Explosive Type    0.0     0.0         1
# 8                    Molotov Cocktail/Petrol Bomb    0.0     0.0         1
# 9                             Gasoline or Alcohol    0.0     0.0         1
# 10                         Unknown Explosive Type    0.0     0.0         0
# 11                   Molotov Cocktail/Petrol Bomb    0.0     0.0         1
# 12                  Rifle/Shotgun (non-automatic)    0.0     0.0         0
# 13                   Molotov Cocktail/Petrol Bomb    0.0     0.0         1
# 14                                     Arson/Fire    0.0     0.0         1
# 15                         Unknown Explosive Type    NaN     NaN         0
# 16                                            NaN    1.0     0.0         0
# 17                                      Pipe Bomb    0.0     0.0         1
# 18                         Unknown Explosive Type    0.0     0.0        -9
# 19                   Molotov Cocktail/Petrol Bomb    0.0     0.0         1
# 20                   Molotov Cocktail/Petrol Bomb    0.0     1.0         1
# 21              Automatic or Semi-Automatic Rifle    0.0     0.0         1
# 22                         Unknown Explosive Type    0.0     0.0         1
# 23                         Unknown Explosive Type    0.0     0.0         0
# 24                                     Arson/Fire    0.0     0.0         1
# 25                                            NaN    1.0     0.0         0
# 26                                        Vehicle    0.0     0.0         1
# 27                                            NaN    0.0     0.0         0
# 28                                   Dynamite/TNT    0.0     0.0         1
# 29                                     Arson/Fire    0.0     0.0         1
# ...                                           ...    ...     ...       ...
# 181661                                 Arson/Fire    1.0     0.0         1
# 181662                                   Landmine    NaN     2.0         0
# 181663                       Other Explosive Type    0.0     0.0         0
# 181664                           Unknown Gun Type    0.0     2.0         0
# 181665                           Unknown Gun Type    0.0     0.0         1
# 181666                                        NaN    NaN     NaN         1
# 181667                                    Vehicle    NaN     NaN        -9
# 181668  Projectile (rockets, mortars, RPGs, etc.)    0.0     0.0         0
# 181669                                    Grenade    0.0     5.0        -9
# 181670                                        NaN    1.0     0.0         0
# 181671                     Unknown Explosive Type    4.0     9.0         0
# 181672                                    Grenade    8.0     3.0        -9
# 181673                                    Vehicle   18.0    14.0        -9
# 181674                                        NaN    5.0     0.0         0
# 181675                                   Landmine    2.0     3.0         1
# 181676                             Remote Trigger    5.0     0.0         1
# 181677                           Unknown Gun Type    0.0     0.0         1
# 181678                                    Grenade    1.0     1.0        -9
# 181679                           Unknown Gun Type   13.0     0.0         0
# 181680  Projectile (rockets, mortars, RPGs, etc.)    0.0     0.0        -9
# 181681                     Unknown Explosive Type    1.0     5.0         1
# 181682                                 Arson/Fire    0.0     0.0         1
# 181683                           Unknown Gun Type    6.0     0.0         0
# 181684          Automatic or Semi-Automatic Rifle    0.0     0.0         0
# 181685                     Unknown Explosive Type    0.0     4.0         1
# 181686                           Unknown Gun Type    1.0     2.0        -9
# 181687  Projectile (rockets, mortars, RPGs, etc.)    2.0     7.0         1
# 181688                                 Arson/Fire    0.0     0.0         1
# 181689                                    Grenade    0.0     0.0        -9
# 181690                     Unknown Explosive Type    0.0     0.0         0
#
#         ishostkid                  dbsource  INT_LOG  INT_IDEO  INT_MISC  \
# 0             0.0                      PGIS        0         0         0
# 1             1.0                      PGIS        0         1         1
# 2             0.0                      PGIS       -9        -9         1
# 3             0.0                      PGIS       -9        -9         1
# 4             0.0                      PGIS       -9        -9         1
# 5             0.0            Hewitt Project       -9        -9         0
# 6             0.0                      PGIS        0         0         0
# 7             0.0            Hewitt Project       -9        -9         0
# 8             0.0            Hewitt Project        0         0         0
# 9             0.0            Hewitt Project        0         0         0
# 10            0.0                      PGIS        0         0         0
# 11            0.0            Hewitt Project       -9        -9         0
# 12            0.0              Hijacking DB       -9        -9         1
# 13            0.0            Hewitt Project       -9        -9         0
# 14            0.0            Hewitt Project        0         0         0
# 15            0.0                      PGIS        0         1         1
# 16            0.0                      PGIS        0         1         1
# 17            0.0            Hewitt Project       -9        -9         0
# 18            0.0            Hewitt Project       -9        -9         0
# 19            0.0            Hewitt Project       -9        -9         0
# 20            0.0            Hewitt Project       -9        -9         0
# 21            0.0                      PGIS        0         0         0
# 22            0.0            Hewitt Project       -9        -9         0
# 23            0.0            Hewitt Project       -9        -9         0
# 24            0.0            Hewitt Project       -9        -9         0
# 25            0.0                      PGIS       -9        -9         1
# 26            0.0                      PGIS       -9        -9         1
# 27            1.0                      PGIS        0         0         0
# 28            0.0            Hewitt Project       -9        -9         0
# 29            0.0            Hewitt Project       -9        -9         0
# ...           ...                       ...      ...       ...       ...
# 181661        0.0  START Primary Collection       -9        -9         0
# 181662        0.0  START Primary Collection        0         0         0
# 181663        0.0  START Primary Collection       -9        -9         0
# 181664        0.0  START Primary Collection       -9        -9         1
# 181665        0.0  START Primary Collection        0         0         0
# 181666        0.0  START Primary Collection        0         0         0
# 181667        0.0  START Primary Collection        0         0         0
# 181668        0.0  START Primary Collection       -9        -9         0
# 181669        0.0  START Primary Collection       -9        -9         0
# 181670        0.0  START Primary Collection        0         1         0
# 181671        0.0  START Primary Collection        0         1         0
# 181672        0.0  START Primary Collection        1         1         0
# 181673        0.0  START Primary Collection        0         1         0
# 181674        0.0  START Primary Collection        0         1         0
# 181675        0.0  START Primary Collection        0         1         1
# 181676        0.0  START Primary Collection        0         0         0
# 181677        0.0  START Primary Collection        0         0         0
# 181678        0.0  START Primary Collection       -9        -9         0
# 181679        0.0  START Primary Collection        0         1         0
# 181680        0.0  START Primary Collection        0         1         1
# 181681        0.0  START Primary Collection        0         0         0
# 181682        0.0  START Primary Collection       -9        -9         0
# 181683        0.0  START Primary Collection        0         0         0
# 181684        1.0  START Primary Collection        0         0         0
# 181685        0.0  START Primary Collection       -9        -9         0
# 181686        0.0  START Primary Collection        0         0         0
# 181687        0.0  START Primary Collection       -9        -9         1
# 181688        0.0  START Primary Collection        0         0         0
# 181689        0.0  START Primary Collection       -9        -9         0
# 181690        0.0  START Primary Collection       -9        -9         0
#
#         INT_ANY
# 0             0
# 1             1
# 2             1
# 3             1
# 4             1
# 5            -9
# 6             0
# 7            -9
# 8             0
# 9             0
# 10            0
# 11           -9
# 12            1
# 13           -9
# 14            0
# 15            1
# 16            1
# 17           -9
# 18           -9
# 19           -9
# 20           -9
# 21            0
# 22           -9
# 23           -9
# 24           -9
# 25            1
# 26            1
# 27            0
# 28           -9
# 29           -9
# ...         ...
# 181661       -9
# 181662        0
# 181663       -9
# 181664        1
# 181665        0
# 181666        0
# 181667        0
# 181668       -9
# 181669       -9
# 181670        1
# 181671        1
# 181672        1
# 181673        1
# 181674        1
# 181675        1
# 181676        0
# 181677        0
# 181678       -9
# 181679        1
# 181680        1
# 181681        0
# 181682       -9
# 181683        0
# 181684        0
# 181685       -9
# 181686        0
# 181687        1
# 181688        0
# 181689       -9
# 181690       -9
#
# [181691 rows x 47 columns]

# %%
### checking again the shape of dataset.
new_df.shape
# Out:
# (181691, 47)

# %%
new_df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'extended', 'country',
#        'country_txt', 'region', 'region_txt', 'provstate', 'city', 'latitude',
#        'longitude', 'specificity', 'vicinity', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'multiple', 'success', 'suicide', 'attacktype1',
#        'attacktype1_txt', 'targtype1', 'targtype1_txt', 'targsubtype1',
#        'targsubtype1_txt', 'target1', 'natlty1', 'natlty1_txt', 'gname',
#        'guncertain1', 'individual', 'weaptype1', 'weaptype1_txt',
#        'weapsubtype1', 'weapsubtype1_txt', 'nkill', 'nwound', 'property',
#        'ishostkid', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY'],
#       dtype='object')

# %%
df2=(new_df.isnull().sum()/len(new_df))*100
df2.head(25)
# Out:
# eventid            0.000000
# iyear              0.000000
# imonth             0.000000
# iday               0.000000
# extended           0.000000
# country            0.000000
# country_txt        0.000000
# region             0.000000
# region_txt         0.000000
# provstate          0.231712
# city               0.238867
# latitude           2.507554
# longitude          2.508104
# specificity        0.003302
# vicinity           0.000000
# crit1              0.000000
# crit2              0.000000
# crit3              0.000000
# doubtterr          0.000550
# multiple           0.000550
# success            0.000000
# suicide            0.000000
# attacktype1        0.000000
# attacktype1_txt    0.000000
# targtype1          0.000000
# dtype: float64

# %% [markdown]
# ## Data Visualization

# %%
v = new_df['iyear'].value_counts()

# %% [markdown]
# ### 1. Number Of Terrorist Activities Each Year

# %%
plt.figure(figsize = (15,7))
sns.set(style = 'darkgrid')
sns.barplot(x = v.index, y = v, data = new_df, palette = 'coolwarm')

plt.xticks(rotation  = 90)

plt.title('Number Of Terrorist Activities Each Year', fontsize = 15)
plt.xlabel('Year',fontsize = 15)
plt.ylabel('Counts',fontsize = 15)
plt.show()

# %% [markdown]
# ### Insights:
#
# From here we can see that most of the attack happend in 2014. & Here we can observe the number of terrorist activities have gone up sharply after 2010.

# %% [markdown]
# ### 2. Country affected by terrorism

# %%
v = df['country_txt'].value_counts()
plt.figure(figsize = (20,60))
sns.set(style = 'darkgrid')
ax = sns.barplot(x = v, y = v.index, data = new_df, palette = 'deep')

plt.xticks(rotation  = 90)

plt.title('Country affected by terrorism', fontsize = 20)
plt.xlabel('Counts',fontsize = 15)
plt.ylabel('Country Name',fontsize = 15)
plt.show()

# %% [markdown]
# ### Insights:
#
# From here we can see that most of the terrorist attack happend in 'Iraq', 'Pakistan', 'Afghanistan', 'India' & 'Colombia'.

# %% [markdown]
# ### 3. Region affected by terrorism

# %%
v = df['region_txt'].value_counts()
plt.figure(figsize = (15,7))
sns.set(style = 'darkgrid')
ax = sns.barplot(x = v.index, y = v, data = new_df, palette = 'coolwarm')

plt.xticks(rotation  = 90)
total = float(len(new_df['region_txt']))

for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='right')
plt.title('Distribution of Attacks per Region (1970-2017)', fontsize = 15)
plt.xlabel('Region Name',fontsize = 15)
plt.ylabel('Counts',fontsize = 15)
plt.show()

# %% [markdown]
# ### Insights:
#
# From here we can see that most of the terrorist attack happend in 'Middle East & North Africa region.The region represents 27.8% of all records between 1970 and 2017.

# %% [markdown]
# ### 4. State affected by terrorism
#
# Let selected top 100 state all over the world.those mostly affected by terrorism.

# %%
v = new_df['provstate'].value_counts()[:75]  # Here we selected  mostly  affected  75 states by terrorism.
plt.figure(figsize = (20,10))
sns.set(style = 'darkgrid')
ax = sns.barplot(x = v.index, y = v, data = new_df, palette = 'Spectral')

plt.xticks(rotation  = 90)

plt.title('State affected by terrorism', fontsize = 20)
plt.xlabel('State Name',fontsize = 15)
plt.ylabel('Counts',fontsize = 15)
plt.show()

# %% [markdown]
# ### Insights:
#
# From here above we can see that most of the terrorist attack happend in 'Baghdad', 'Northern Ireland' state from 1970 to 2017.

# %% [markdown]
# ### 5. City affected by terrorism

# %%
v = new_df['city'].value_counts()[:75]
plt.figure(figsize = (20,20))
sns.set(style = 'darkgrid')
ax = sns.barplot(x = v, y = v.index, data = new_df, palette = 'vlag')

plt.xticks(rotation  = 90)

plt.title('City affected by terrorism', fontsize = 20)
plt.xlabel('Counts',fontsize = 15)
plt.ylabel('City Name',fontsize = 15)
plt.show()

# %% [markdown]
# ### Insights:
#
# From here above we can see that most of the terrorist attack happend in 'Unknown', 'Baghdad', 'Karachi' & 'Lima' city from 1970 to 2017.

# %% [markdown]
# ### 6. Terrorist attack Successed or failed

# %%
v = df['success'].value_counts()
fig = plt.gcf()
fig.set_size_inches((6,6))

cmap = plt.get_cmap('Set1')
plt.pie(v, labels = ['Successed', 'failed'], autopct = '%0.02f', colors=['green','red'],
        labeldistance = 1.1, wedgeprops= dict(width = 0.6), shadow = True)
plt.title('Terrorist attack Successed or failed (1970-2017)', fontsize = (15))
plt.show()

# %% [markdown]
# ## Insights:
#
# Here form above, we can see that approx 89% terrorist attack is sucessed and 11% is failed form 1970 to 2017.

# %% [markdown]
# ### 7. Suicide or Not Suicide

# %%
v = df['suicide'].value_counts()
fig = plt.gcf()
fig.set_size_inches((6,6))

cmap = plt.get_cmap('Set3')
color = cmap(np.arange(len(v)))
plt.pie(v, labels = ['Suicide', 'Not Suicide'], autopct = '%0.02f', colors = color, 
        labeldistance = 1.1, wedgeprops= dict(width = 0.6), shadow = True)
plt.title('Suicide or Not Suicide (1970-2017)', fontsize = (15))
plt.show()

# %% [markdown]
# ### Insights:
#
# From above we can see that approx 97% terrorist attack was suicide & 3% wasn't suicide.

# %% [markdown]
# ### 8. Attacktype

# %%
v = df['attacktype1_txt'].value_counts()
plt.figure(figsize = (12,7))
sns.set(style = 'darkgrid')
ax = sns.barplot(x = v.index, y = v, data = new_df, palette = 'mako')

plt.xticks(rotation  = 90)
total = float(len(new_df['attacktype1_txt']))

for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='right')
plt.title('Attack type (1970-2017)', fontsize =15)
plt.xlabel('Attack type',fontsize = 15)
plt.ylabel('Counts',fontsize = 15)
plt.show()

# %% [markdown]
# ### Insights:
#
# From above we can see that Bombing/Explosion is most common terrorist attack.

# %% [markdown]
# ### 9. Target type

# %%
v = df['targtype1_txt'].value_counts()
plt.figure(figsize = (20,10))
sns.set(style = 'darkgrid')
ax = sns.barplot(x = v.index, y = v, data = new_df, palette = 'Paired')

plt.xticks(rotation  = 90)
total = float(len(new_df['targtype1_txt']))

for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='right')
plt.title('Target type (1970-2017)', fontsize = 20)
plt.xlabel('Target type',fontsize = 15)
plt.ylabel('Counts',fontsize = 15)
plt.show()

# %% [markdown]
# ### Insights:
#
# From above we can see terrorist attack mostly affected the Private Citizens & Property. that is approx 49% from (1970-2017).

# %% [markdown]
# ### 10. Top 20 terrorist group name

# %%
v  = df['gname'].value_counts()[:20]  # top 20 terrorist group name
plt.figure(figsize = (20,10))
sns.set(style = 'darkgrid')
sns.barplot(x = v.index, y = v, data = new_df)
plt.xticks(rotation  = 90)

plt.title('Top 20 terrorist Group name (1970-2017)', fontsize = 20)
plt.xlabel('Terrorist Group name',fontsize = 15)
plt.ylabel('Counts',fontsize = 15)
plt.show()

# %% [markdown]
# ### Insights:
#
# From above we can see that some famous terrorist group name was 'Unknown', 'Taliban', 'Islamic State of Iraq and the Levant (ISIL) form 1970 to 2017.

# %% [markdown]
# ### 11. Weapon type

# %%
v= df['weaptype1_txt'].value_counts()
plt.figure(figsize = (14,7))

sns.barplot(x = v.index, y = v, data = new_df, palette = 'viridis')
plt.xticks(rotation = 90)

plt.title('Weapon type (1970-2017)', fontsize = 18)
plt.xlabel('Weapon type',fontsize = 15)
plt.ylabel('Counts',fontsize = 15)
plt.show()

# %% [markdown]
# ### Insights:
#
# From above we can see that most famous weapon type was 'Explosives' form 1970 to 2017.

# %% [markdown]
# ### 12. Successful or Unsuccessful terrorist strike

# %%
sns.set(font_scale=1.5)
fig = plt.figure(figsize=(20,10))
sns.countplot(x='iyear',data=new_df,hue='success', orient='v',palette = 'coolwarm')
plt.xlabel('Year',fontsize=17)
plt.ylabel('Counts', fontsize=17)

plt.title('Successful or Unsuccessful terrorist strike', fontsize=24)

plt.xticks(rotation=90)
plt.tight_layout()

# %% [markdown]
# ### 13. The incident was/wasn't a suicide attack (1970-2017)

# %%
sns.set(style = 'darkgrid')
fig = plt.figure(figsize=(20,10))
sns.countplot(x='iyear',data=new_df,hue='suicide',  palette = 'Blues',edgecolor=sns.color_palette("YlOrBr", 10));
plt.title("The incident was/wasn't a suicide attack", fontsize=25)
plt.xlabel('Year',fontsize=18)
plt.ylabel('Counts', fontsize=18)
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 14. Highest No. of people killed by country

# %%
c = new_df.groupby('country_txt')
x = c['nkill'].agg(np.sum)

# %%
plt.figure(figsize = (20,20))
sns.barplot(x = x.nlargest(n = 40), y= x.nlargest(n = 40).index)  #n=40(selected 40 largest country based on terrorism activity)
plt.title("Highest No. of  people killed by country", fontsize=20)
plt.xlabel('NO. of people killed',fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insights:
#
# Highest Number of death of people happend in Iraq, Afganisthan, Pakisthan, Nigeria & India from 1970 to 2017.

# %% [markdown]
# ### 15. Highest No. of people killed by Region

# %%
plt.figure(figsize = (20,10))
region_grp = df.groupby('region_txt')
v = region_grp['nkill'].agg(np.sum)

plt.figure(figsize=(20,8))
plt.plot(v,'g--')
plt.xticks(rotation=90)
plt.title('Highest No. of  people killed by Region(1970-2017)', fontsize = 20)
plt.xlabel('Region', fontsize = 17)
plt.ylabel('No. of people Killed', fontsize=  17)
plt.show()

# %% [markdown]
# ### Insights:
#
# Highest No. of people killed in Middle east and Africa region(1970-2017).

# %% [markdown]
# ### 16. Highest No. of people killed by State

# %%
state_grp = df.groupby('provstate')
v = state_grp['nkill'].agg(np.sum)
value = v.nlargest(n= 30)  # top 30 states where people killed by terrorist attack
plt.figure(figsize=(20,20))
sns.barplot(x = value, y = value.index, palette = 'cubehelix')

plt.xticks(rotation=90)
plt.title('Highest No. of  people killed by State(1970-2017)', fontsize = 20)
plt.xlabel('No. of people Killed', fontsize = 20)
plt.ylabel('State', fontsize=  20)
plt.show()

# %% [markdown]
# ### Insights:
#
# Highest No. of people killed in 'Baghdad', 'Unknown', 'Nineveh', 'Borno' , 'Al Anbar' states from(1970-2017).

# %% [markdown]
# ### 17. Highest No. of people killed by city

# %%
state_grp = df.groupby('city')
v = state_grp['nkill'].agg(np.sum)
value = v.nlargest(n= 30)  # top 30 cities where highest people killed by terrorist attack
plt.figure(figsize=(20,20))
sns.barplot(x = value, y = value.index)

plt.xticks(rotation=90)
plt.title('Highest No. of  people killed by city(1970-2017)', fontsize = 20)
plt.xlabel('No. of people Killed', fontsize = 20)
plt.ylabel('City', fontsize=  20)
plt.show()

# %% [markdown]
# ### Insights:
#
# Highest No. of people killed in 'Unknown', 'Baghdad', 'Mosul', 'Mogadishu', & 'Karachi', 'New York City' cities from(1970-2017).

# %% [markdown]
# ### 18. Terrorist Activities by Region each Year

# %%
pd.crosstab(new_df.iyear, new_df.region_txt).plot(kind='area',figsize=(20,8))
plt.title('Terrorist Activities by Region each Year')
plt.ylabel('Number of Attacks')
plt.show()

# %% [markdown]
# ### Insights:
#
# Form the analysis Number of activities have gone up sharply after 2010 from(1970-2017).

# %% [markdown]
# ### 19. Focusing on india

# %%
terror_india = new_df[new_df['country_txt'] == 'India']

# %% [markdown]
# ### 20. Number Of terrorist activities each Year in India

# %%
plt.subplots(figsize=(20,8))
sns.countplot('iyear',data=terror_india,palette='Set1',edgecolor=sns.color_palette('dark',10))
plt.xticks(rotation=90)
plt.title('Number Of terrorist activities each Year in India')
plt.show()

# %% [markdown]
# ### Insights:
#
# Form the analysis Number of activities have gone up sharply after 2010 from(1970-2017) & and NO. of terrorist activity is higer in 2016 in india.

# %% [markdown]
# ### 21. Number Of Total Attacks in Each Indian City

# %%
plt.subplots(figsize=(20,8))
city_attacks_india = terror_india.city.value_counts()[:15].reset_index()
city_attacks_india.columns = ['City', 'Total Attacks']
city_attacks_india.drop(1, inplace=True)
sns.barplot(x=city_attacks_india.City, y=city_attacks_india['Total Attacks'], palette='Set2',
            edgecolor=sns.color_palette('dark',10))
plt.xticks(rotation=90)
plt.title('Number Of Total Attacks in Each Indian City')
plt.show()

# %% [markdown]
# ### Insights:
#
# Form the analysis in Srinagar city terrorist activity is higher compare to another cities in india

# %% [markdown]
# ### 22. Terrorist Groups with Highest Terror Attacks in India

# %%
sns.barplot(y = terror_india['gname'].value_counts()[1:10].values,x = terror_india['gname'].value_counts()[1:10].index,palette='Spectral')
plt.xticks(rotation=90)
fig=plt.gcf()
fig.set_size_inches(15,5)
plt.title('Terrorist Groups with Highest Terror Attacks in India')
plt.show()

# %% [markdown]
# ### Insights:
#
# Form the analysis, 'Communist Party of India - Maoist (CPI-Maoist)' is terrorist group with highest terror attacks in india.

# %%
terror_india['gname'].value_counts()[1:10]
# Out:
# Communist Party of India - Maoist (CPI-Maoist)    1877
# Maoists                                           1396
# Sikh Extremists                                    710
# United Liberation Front of Assam (ULFA)            357
# Hizbul Mujahideen (HM)                             199
# Lashkar-e-Taiba (LeT)                              187
# National Democratic Front of Bodoland (NDFB)       174
# Garo National Liberation Army                      166
# Muslim Separatists                                 118
# Name: gname, dtype: int64
